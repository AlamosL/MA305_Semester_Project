# %% [markdown]
# # Neural Network

# %%
## 1D Neural Network with Multi-input/Single Output
## Harley Valdez, Ryan Hanrahan, Brett Bartoshevich
## Alexa Manssa, Leila Alamos
## MA305 Project
## 3/4/22
## Credit to: Emily Diegel
## for References in Dataset & Neural Network Model Training

import pandas as pd
dataset = pd.read_csv(r'C:\Users\17818\Downloads\winequality-red.csv')
print(dataset)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import seaborn as sns
import matplotlib.pyplot as plt

train_dataset = dataset.sample(frac=0.8,random_state=0)
test_dataset = dataset.drop(train_dataset.index)

sns.pairplot(train_dataset[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar']], diag_kind='kde')

train_labels = train_dataset.pop('fixed acidity')
test_labels = test_dataset.pop('fixed acidity')

def norm(x):
  return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)

def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation=tf.nn.relu, input_shape=[len(train_dataset.keys())]),
    layers.Dense(64, activation=tf.nn.relu),
    layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error', 'mean_squared_error'])
  return model
model = build_model()
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11300/1153413851.py in <module>
#      15 def norm(x):
#      16   return (x - train_stats['mean']) / train_stats['std']
# ---> 17 normed_train_data = norm(train_dataset)
#      18 normed_test_data = norm(test_dataset)
#      19
#
# ~\AppData\Local\Temp/ipykernel_11300/1153413851.py in norm(x)
#      14
#      15 def norm(x):
# ---> 16   return (x - train_stats['mean']) / train_stats['std']
#      17 normed_train_data = norm(train_dataset)
#      18 normed_test_data = norm(test_dataset)
#
# NameError: name 'train_stats' is not defined

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print(val_loss, val_acc)

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[0])
#plt.show() for images

# %%
model.save('Neural_Network.model')

# %%
new_model = tf.keras.models.load_model('Nueral_Network.model')

# %%
predictions = new_model.predict([x_test])

# %%
print(predictions)

# %%
import numpy as np

# %%
data = np.zeros(10)
print(data)

# %%
#mnist = tf.keras.datasets.mnist # data set size of wine quanitites
#(x_train, y_train), (x_test, y_test) = mnist.load_data()
#x_train = tf.keras.utils.normalize(x_train, axis=1)
#x_test = tf.keras.utils.normalize(x_test, axis=1)

#model = tf.keras.models.Sequential([
#])
#model.add(tf.keras.layers.Flatten())
#model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
#model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
#model.add(tf.keras.layers.Dense(1, activation=tf.nn.sigmoid)) #change 10 

#model.compile(loss='mean_absolute_error',
               # optimizer=tf.keras.optimizers.Adam(0.001))

#model.summary()

# %%
##Camera Code
open camera

import subprocess

Subprocess.run('name of camera', shell=True)

close camera

Subprocess.run('Taskhill /IM name of camera /F', shell=True)
